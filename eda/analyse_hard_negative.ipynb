# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../dataset/hard_mining/hard_mining_fold2.csv')
# df = pd.read_csv('../macaulaylibrary.csv')
losses = np.zeros(len(df))
for idx, row in df.iterrows():
    losses[idx] = np.array(row[2], dtype='float')
losses[::-1].sort()
plt.plot(np.log(losses))
# plt.plot(losses)

# %%
df
# Out:
#         id                                               path          loss
# 0        0  /home/datasets/rain_forest/d...  4.017027e-03
# 1        1  /home/datasets/rain_forest/d...  2.989351e-01
# 2        2  /home/datasets/rain_forest/d...  4.467115e-03
# 3        3  /home/datasets/rain_forest/d...  7.171217e-03
# 4        4  /home/datasets/rain_forest/d...  3.391631e-05
# ...    ...                                                ...           ...
# 3919  3919  /home/datasets/rain_forest/d...  3.307499e-04
# 3920  3920  /home/datasets/rain_forest/d...  1.493954e-01
# 3921  3921  /home/datasets/rain_forest/d...  2.561096e-05
# 3922  3922  /home/datasets/rain_forest/d...  1.316270e-07
# 3923  3923  /home/datasets/rain_forest/d...  2.264623e-01
#
# [3924 rows x 3 columns]

# %%
df.sort_values(by=['loss'])
# Out:
#         id                                               path      loss
# 2407  2407  /home/datasets/rain_forest/d...  0.000000
# 292    292  /home/datasets/rain_forest/d...  0.000000
# 2678  2678  /home/datasets/rain_forest/d...  0.000000
# 1353  1353  /home/datasets/rain_forest/d...  0.000000
# 3267  3267  /home/datasets/rain_forest/d...  0.000000
# ...    ...                                                ...       ...
# 2316  2316  /home/datasets/rain_forest/d...  0.905582
# 3807  3807  /home/datasets/rain_forest/d...  0.909253
# 1360  1360  /home/datasets/rain_forest/d...  1.039264
# 679    679  /home/datasets/rain_forest/d...  1.108335
# 2472  2472  /home/datasets/rain_forest/d...  1.724039
#
# [3924 rows x 3 columns]

# %%
t = np.load('weight.npy')
t.sort()
plt.plot(t)
